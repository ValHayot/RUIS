# %%
from report import analysis

# %% [markdown]
# # Dummy applications

# %% [markdown]
# ## CPU stress test

# %%
analysis("example-data/cpu")
# Out:
# ...
#     CPU Analysis
# ...
# Total CPU core:
# 24
#
# Total CPU time (seconds):
# 796.820
#
# Parallel CPU time (seconds):
# 45.222
#
# Makes span (seconds):
# 58.299
# ...
#     Disk I/O
# ...
# Data transfer (Gb):
# Read:
# [DSK:nvme0n1]RGBytes   0.000
# [DSK:nvme1n1]RGBytes   0.000
#
# Write:
# [DSK:nvme0n1]WGBytes   0.000
# [DSK:nvme1n1]WGBytes   0.000
#
# Total: 0.000
#
# Total I/O time (seconds):
# 0.000
#
# Parallel I/O time (seconds):
# 0.000
# ...
#     Network I/O
# ...
# Data transfer (Gb):
# Read:
# [NET:lo]RxGB                0.000
# [NET:enp7s0]RxGB            0.000
# [NET:enp6s0]RxGB            0.000
# [NET:br-8b161ea8f973]RxGB   0.000
# [NET:br-9c7347618dfb]RxGB   0.000
# [NET:docker0]RxGB           0.000
#
# Write:
# [NET:lo]TxGB                0.000
# [NET:enp7s0]TxGB            0.000
# [NET:enp6s0]TxGB            0.000
# [NET:br-8b161ea8f973]TxGB   0.000
# [NET:br-9c7347618dfb]TxGB   0.000
# [NET:docker0]TxGB           0.000
#
# Total: 0.000
#
# Total I/O time (seconds):
# 0.000
#
# ...

# %% [markdown]
# ## Disk test

# %%
analysis("example-data/disk")
# Out:
# ...
#     CPU Analysis
# ...
# Total CPU core:
# 24
#
# Total CPU time (seconds):
# 58.123
#
# Parallel CPU time (seconds):
# 33.498
#
# Makes span (seconds):
# 33.897
# ...
#     Disk I/O
# ...
# Data transfer (Gb):
# Read:
# [DSK:nvme0n1]RGBytes   0.000
# [DSK:nvme1n1]RGBytes   0.000
#
# Write:
# [DSK:nvme0n1]WGBytes   23.138
# [DSK:nvme1n1]WGBytes    0.000
#
# Total: 23.138
#
# Total I/O time (seconds):
# 12.562
#
# Parallel I/O time (seconds):
# 12.562
# ...
#     Network I/O
# ...
# Data transfer (Gb):
# Read:
# [NET:lo]RxGB                0.000
# [NET:enp7s0]RxGB            0.000
# [NET:enp6s0]RxGB            0.000
# [NET:br-8b161ea8f973]RxGB   0.000
# [NET:br-9c7347618dfb]RxGB   0.000
# [NET:docker0]RxGB           0.000
#
# Write:
# [NET:lo]TxGB                0.000
# [NET:enp7s0]TxGB            0.000
# [NET:enp6s0]TxGB            0.000
# [NET:br-8b161ea8f973]TxGB   0.000
# [NET:br-9c7347618dfb]TxGB   0.000
# [NET:docker0]TxGB           0.000
#
# Total: 0.000
#
# Total I/O time (seconds):
# 0.000
#
# ...

# %% [markdown]
# ## Network test

# %%
analysis("example-data/network")
# Out:
# ...
#     CPU Analysis
# ...
# Total CPU core:
# 24
#
# Total CPU time (seconds):
# 158.731
#
# Parallel CPU time (seconds):
# 68.527
#
# Makes span (seconds):
# 96.497
# ...
#     Disk I/O
# ...
# Data transfer (Gb):
# Read:
# [DSK:nvme0n1]RGBytes   0.000
# [DSK:nvme1n1]RGBytes   0.000
#
# Write:
# [DSK:nvme0n1]WGBytes   0.001
# [DSK:nvme1n1]WGBytes   0.000
#
# Total: 0.001
#
# Total I/O time (seconds):
# 0.100
#
# Parallel I/O time (seconds):
# 0.100
# ...
#     Network I/O
# ...
# Data transfer (Gb):
# Read:
# [NET:lo]RxGB                11.658
# [NET:enp7s0]RxGB             0.000
# [NET:enp6s0]RxGB             0.000
# [NET:br-8b161ea8f973]RxGB    0.000
# [NET:br-9c7347618dfb]RxGB    0.000
# [NET:docker0]RxGB            0.000
#
# Write:
# [NET:lo]TxGB                11.658
# [NET:enp7s0]TxGB             0.000
# [NET:enp6s0]TxGB             0.000
# [NET:br-8b161ea8f973]TxGB    0.000
# [NET:br-9c7347618dfb]TxGB    0.000
# [NET:docker0]TxGB            0.000
#
# Total: 23.316
#
# Total I/O time (seconds):
# 156.033
#
# ...

# %% [markdown]
# # Neuroimaging Applications

# %% [markdown]
# ## BET participant analysis

# %%
analysis("example-data/bet_participant")
# Out:
# ...
#     CPU Analysis
# ...
# Total CPU core:
# 24
#
# Total CPU time (seconds):
# 58.062
#
# Parallel CPU time (seconds):
# 42.898
#
# Makes span (seconds):
# 42.898
# ...
#     Disk I/O
# ...
# Data transfer (Gb):
# Read:
# [DSK:nvme0n1]RGBytes   0.070
# [DSK:nvme1n1]RGBytes   0.000
#
# Write:
# [DSK:nvme0n1]WGBytes   0.046
# [DSK:nvme1n1]WGBytes   0.000
#
# Total: 0.116
#
# Total I/O time (seconds):
# 2.494
#
# Parallel I/O time (seconds):
# 2.494
# ...
#     Network I/O
# ...
# Data transfer (Gb):
# Read:
# [NET:lo]RxGB                0.000
# [NET:enp7s0]RxGB            0.000
# [NET:enp6s0]RxGB            0.000
# [NET:br-8b161ea8f973]RxGB   0.000
# [NET:br-9c7347618dfb]RxGB   0.000
# [NET:docker0]RxGB           0.000
#
# Write:
# [NET:lo]TxGB                0.000
# [NET:enp7s0]TxGB            0.000
# [NET:enp6s0]TxGB            0.000
# [NET:br-8b161ea8f973]TxGB   0.000
# [NET:br-9c7347618dfb]TxGB   0.000
# [NET:docker0]TxGB           0.000
#
# Total: 0.000
#
# Total I/O time (seconds):
# 0.000
#
# ...

# %% [markdown]
# ## BET group analysis

# %%
analysis("example-data/bet_group")
# Out:
# ...
#     CPU Analysis
# ...
# Total CPU core:
# 24
#
# Total CPU time (seconds):
# 4.281
#
# Parallel CPU time (seconds):
# 3.600
#
# Makes span (seconds):
# 3.600
# ...
#     Disk I/O
# ...
# Data transfer (Gb):
# Read:
# [DSK:nvme0n1]RGBytes   0.000
# [DSK:nvme1n1]RGBytes   0.000
#
# Write:
# [DSK:nvme0n1]WGBytes   0.000
# [DSK:nvme1n1]WGBytes   0.000
#
# Total: 0.000
#
# Total I/O time (seconds):
# 0.000
#
# Parallel I/O time (seconds):
# 0.000
# ...
#     Network I/O
# ...
# Data transfer (Gb):
# Read:
# [NET:lo]RxGB                0.000
# [NET:enp7s0]RxGB            0.000
# [NET:enp6s0]RxGB            0.000
# [NET:br-8b161ea8f973]RxGB   0.000
# [NET:br-9c7347618dfb]RxGB   0.000
# [NET:docker0]RxGB           0.000
#
# Write:
# [NET:lo]TxGB                0.000
# [NET:enp7s0]TxGB            0.000
# [NET:enp6s0]TxGB            0.000
# [NET:br-8b161ea8f973]TxGB   0.000
# [NET:br-9c7347618dfb]TxGB   0.000
# [NET:docker0]TxGB           0.000
#
# Total: 0.000
#
# Total I/O time (seconds):
# 0.000
#
# ...

# %% [markdown]
# ## MRIQC participant analysis

# %%
analysis("example-data/mriqc_participant")
# Out:
# ...
#     CPU Analysis
# ...
# Total CPU core:
# 24
#
# Total CPU time (seconds):
# 4132.876
#
# Parallel CPU time (seconds):
# 943.003
#
# Makes span (seconds):
# 974.000
# ...
#     Disk I/O
# ...
# Data transfer (Gb):
# Read:
# [DSK:nvme0n1]RGBytes   0.298
# [DSK:nvme1n1]RGBytes   0.000
#
# Write:
# [DSK:nvme0n1]WGBytes   0.067
# [DSK:nvme1n1]WGBytes   0.000
#
# Total: 0.365
#
# Total I/O time (seconds):
# 24.597
#
# Parallel I/O time (seconds):
# 24.497
# ...
#     Network I/O
# ...
# Data transfer (Gb):
# Read:
# [NET:lo]RxGB                0.004
# [NET:enp7s0]RxGB            0.000
# [NET:enp6s0]RxGB            0.000
# [NET:br-8b161ea8f973]RxGB   0.000
# [NET:br-9c7347618dfb]RxGB   0.000
# [NET:docker0]RxGB           0.000
#
# Write:
# [NET:lo]TxGB                0.004
# [NET:enp7s0]TxGB            0.000
# [NET:enp6s0]TxGB            0.000
# [NET:br-8b161ea8f973]TxGB   0.000
# [NET:br-9c7347618dfb]TxGB   0.000
# [NET:docker0]TxGB           0.000
#
# Total: 0.007
#
# Total I/O time (seconds):
# 0.100
#
# ...

# %% [markdown]
# ## MRIQC group analysis

# %%
analysis("example-data/mriqc_group")
# Out:
# ...
#     CPU Analysis
# ...
# Total CPU core:
# 24
#
# Total CPU time (seconds):
# 3.256
#
# Parallel CPU time (seconds):
# 2.011
#
# Makes span (seconds):
# 2.298
# ...
#     Disk I/O
# ...
# Data transfer (Gb):
# Read:
# [DSK:nvme0n1]RGBytes   0.000
# [DSK:nvme1n1]RGBytes   0.000
#
# Write:
# [DSK:nvme0n1]WGBytes   0.000
# [DSK:nvme1n1]WGBytes   0.000
#
# Total: 0.001
#
# Total I/O time (seconds):
# 0.192
#
# Parallel I/O time (seconds):
# 0.192
# ...
#     Network I/O
# ...
# Data transfer (Gb):
# Read:
# [NET:lo]RxGB                0.000
# [NET:enp7s0]RxGB            0.000
# [NET:enp6s0]RxGB            0.000
# [NET:br-8b161ea8f973]RxGB   0.000
# [NET:br-9c7347618dfb]RxGB   0.000
# [NET:docker0]RxGB           0.000
#
# Write:
# [NET:lo]TxGB                0.000
# [NET:enp7s0]TxGB            0.000
# [NET:enp6s0]TxGB            0.000
# [NET:br-8b161ea8f973]TxGB   0.000
# [NET:br-9c7347618dfb]TxGB   0.000
# [NET:docker0]TxGB           0.000
#
# Total: 0.000
#
# Total I/O time (seconds):
# 0.000
#
# ...
